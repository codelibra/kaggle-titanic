# %%
# %store -r train
# %store -r test
# %store -r targets
# Out:
# /Users/shiv/.bin/anaconda/lib/python2.7/site-packages/numexpr/cpuinfo.py:76: UserWarning: [Errno 2] No such file or directory
#   stacklevel=stacklevel + 1):

# %%
from sklearn.linear_model import LogisticRegression
# Out:
# /Library/Python/2.6/site-packages/sklearn/__check_build/__init__.py:44: RuntimeWarning: compiletime version 2.6 of module 'sklearn.check_build._check_build' does not match runtime version 2.7
#   from ._check_build import check_build
# /Library/Python/2.6/site-packages/sklearn/utils/__init__.py:10: RuntimeWarning: compiletime version 2.6 of module 'sklearn.utils.murmurhash' does not match runtime version 2.7
#   from .murmurhash import murmurhash3_32
# /Library/Python/2.6/site-packages/sklearn/utils/extmath.py:24: RuntimeWarning: compiletime version 2.6 of module 'sklearn.utils._logistic_sigmoid' does not match runtime version 2.7
#   from ._logistic_sigmoid import _log_logistic_sigmoid
# /Library/Python/2.6/site-packages/sklearn/utils/extmath.py:26: RuntimeWarning: compiletime version 2.6 of module 'sklearn.utils.sparsefuncs_fast' does not match runtime version 2.7
#   from .sparsefuncs_fast import csr_row_norms
# ...

# %%
train_new = train['PassengerId']

# %%
train_test = train.filter(['PassengerId','Age','Sex'])

# %%
train_test
# Out:
#      PassengerId     Age  Sex
# 0              1  0.2750  1.0
# 1              2  0.4750  0.0
# 2              3  0.3250  0.0
# 3              4  0.4375  0.0
# 4              5  0.4375  1.0
# 5              6  0.3250  1.0
# 6              7  0.6750  1.0
# 7              8  0.0250  1.0
# 8              9  0.3375  0.0
# 9             10  0.1750  0.0
# 10            11  0.0500  0.0
# 11            12  0.7250  0.0
# 12            13  0.2500  1.0
# 13            14  0.4875  1.0
# 14            15  0.1750  0.0
# 15            16  0.6875  0.0
# 16            17  0.0250  1.0
# 17            18  0.3750  1.0
# 18            19  0.3875  0.0
# 19            20  0.3875  0.0
# 20            21  0.4375  1.0
# 21            22  0.4250  1.0
# 22            23  0.1875  0.0
# 23            24  0.3500  1.0
# 24            25  0.1000  0.0
# 25            26  0.4750  0.0
# 26            27  0.3250  1.0
# 27            28  0.2375  1.0
# 28            29  0.2250  0.0
# 29            30  0.3250  1.0
# ...

# %%
train.shape
# Out:
# (891, 64)

# %%
clf = LogisticRegression(penalty='L2')

# %%
clf.fit(train_test,targets)

# %%
train_new.shape
# Out:
# (892,)
